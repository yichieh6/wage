# %% [markdown]
# ### 1. 匯入必要套件

# %%
import pandas as pd
import sqlite3
from pandasql import sqldf

# %% [markdown]
# ### 2. 載入資料

# %%
# 讀取 CSV 檔案
df = pd.read_csv('data/df_combined.csv')

# 顯示前幾行
df.head()
# Out:
#                      Category    Category_Type    Education  Salary  \
# 0               All Employees            Total  Junior High  875.00
# 1                        Male           Gender  Junior High  875.00
# 2                      Female           Gender  Junior High  906.25
# 3  Small & Medium Enterprises  Enterprise Size  Junior High  875.00
# 4  Large Enterprises & Others  Enterprise Size  Junior High  937.50
#
#    Real Salary Country  Population
# 0  2049.780381  Taiwan         NaN
# 1  2049.780381  Taiwan         NaN
# 2  2122.986823  Taiwan         NaN
# 3  2049.780381  Taiwan         NaN
# 4  2196.193265  Taiwan         NaN

# %% [markdown]
# ### 3. Calculate All Employees Salary by Country and Education
#
# This query computes the weighted average salary for all employees across different education levels. For Japan, we use population-weighted averages; for Taiwan, we use the original values.

# %%
# 建立 SQLite 資料庫連線
conn = sqlite3.connect(':memory:')

# 將 DataFrame 匯入資料庫
df.to_sql('wage_data', conn, index=False, if_exists='replace')
# Out:
# 234

# %%
query = """
SELECT 
    ae.Country,
    ae.Education,
    ind.min_salary,
    ind.max_salary,
    ae.salary,
    ae.real_salary,
    ae.Population
FROM (
    SELECT 
        Country,
        Education,
        CASE 
            WHEN Population IS NOT NULL AND Population > 0 
            THEN SUM(Salary * Population) / SUM(Population)
            ELSE Salary
        END as salary,
        CASE 
            WHEN Population IS NOT NULL AND Population > 0 
            THEN SUM("Real Salary" * Population) / SUM(Population)
            ELSE "Real Salary"
        END as real_salary,
        SUM(Population) as Population
    FROM wage_data
    WHERE Category = 'All Employees'
    GROUP BY Country, Education
) ae
LEFT JOIN (
    SELECT 
        Country,
        Education,
        MIN(Salary) as min_salary,
        MAX(Salary) as max_salary
    FROM wage_data
    WHERE Category_Type = 'Industry'
    GROUP BY Country, Education
) ind ON ae.Country = ind.Country AND ae.Education = ind.Education
ORDER BY ae.Country,
    CASE ae.Education
        WHEN 'Junior High' THEN 1
        WHEN 'Senior High' THEN 2
        WHEN 'Junior College' THEN 3
        WHEN 'University' THEN 4
        WHEN 'Graduate School' THEN 5
        ELSE 6
    END
"""

all_employees = pd.read_sql_query(query, conn)
all_employees
# Out:
#   Country        Education   min_salary   max_salary       salary  \
# 0   Japan      Junior High  1195.862069  1749.655172  1522.068966
# 1   Japan      Senior High  1268.965517  1412.413793  1362.068966
# 2   Japan   Junior College  1330.344828  1831.724138  1538.810605
# 3   Japan       University  1513.103448  2226.896552  1712.413793
# 4   Japan  Graduate School  1644.137931  2297.241379  1982.068966
# 5  Taiwan      Junior High   875.000000   906.250000   875.000000
# 6  Taiwan      Senior High   875.000000  1062.500000   906.250000
# 7  Taiwan   Junior College   937.500000  1187.500000  1000.000000
# 8  Taiwan       University   968.750000  1343.750000  1062.500000
# 9  Taiwan  Graduate School  1031.250000  1843.750000  1625.000000
#
#    real_salary  Population
# 0  2367.771698       400.0
# 1  2118.871366    107730.0
# 2  2393.815446    115260.0
# 3  2663.877266    292210.0
# 4  3083.360154     31170.0
# 5  2049.780381         NaN
# 6  2122.986823         NaN
# 7  2342.606149         NaN
# 8  2489.019034         NaN
# 9  3806.734993         NaN

# %% [markdown]
# ### 4. Industries with Salaries Above All Employees Average
#
# This query identifies industries where salaries exceed the average for all employees at the same education level and country.

# %%
query = """
SELECT 
    i.Country, 
    i.Education, 
    i.Category, 
    i.Salary,
    ae.salary as all_employees_salary
FROM wage_data i
JOIN (
    SELECT 
        Country,
        Education,
        CASE 
            WHEN Population IS NOT NULL AND Population > 0 
            THEN SUM(Salary * Population) / SUM(Population)
            ELSE Salary
        END as salary
    FROM wage_data
    WHERE Category = 'All Employees'
    GROUP BY Country, Education
) ae ON i.Country = ae.Country AND i.Education = ae.Education
WHERE i.Category_Type = 'Industry' 
    AND i.Salary > ae.salary
ORDER BY i.Country, i.Education, i.Salary DESC
"""
above_average = pd.read_sql_query(query, conn)
above_average
# Out:
#    Country        Education  \
# 0    Japan  Graduate School
# 1    Japan  Graduate School
# 2    Japan  Graduate School
# 3    Japan  Graduate School
# 4    Japan  Graduate School
# 5    Japan  Graduate School
# 6    Japan  Graduate School
# 7    Japan  Graduate School
# 8    Japan   Junior College
# 9    Japan   Junior College
# 10   Japan   Junior College
# 11   Japan   Junior College
# 12   Japan   Junior College
# 13   Japan   Junior College
# 14   Japan   Junior College
# 15   Japan   Junior College
# 16   Japan   Junior College
# 17   Japan   Junior College
# 18   Japan      Junior High
# 19   Japan      Junior High
# 20   Japan      Junior High
# 21   Japan      Senior High
# 22   Japan      Senior High
# 23   Japan      Senior High
# 24   Japan      Senior High
# 25   Japan      Senior High
# 26   Japan      Senior High
# 27   Japan       University
# 28   Japan       University
# 29   Japan       University
# 30   Japan       University
# 31  Taiwan  Graduate School
# 32  Taiwan  Graduate School
# 33  Taiwan   Junior College
# 34  Taiwan   Junior College
# 35  Taiwan   Junior College
# 36  Taiwan   Junior College
# 37  Taiwan      Junior High
# 38  Taiwan      Senior High
# 39  Taiwan      Senior High
# 40  Taiwan      Senior High
# 41  Taiwan      Senior High
# 42  Taiwan      Senior High
# 43  Taiwan      Senior High
# 44  Taiwan      Senior High
# 45  Taiwan      Senior High
# 46  Taiwan       University
# 47  Taiwan       University
# 48  Taiwan       University
# 49  Taiwan       University
# 50  Taiwan       University
# 51  Taiwan       University
# 52  Taiwan       University
#
#                                              Category       Salary  \
# 0                                  Mining & Quarrying  2297.241379
# 1                                 Finance & Insurance  2289.655172
# 2                                           Education  2184.137931
# 3                                         Real Estate  2176.551724
# 4   Publishing, Audio-Visual & Information Communi...  2124.137931
# 5                                        Construction  2048.275862
# 6                                   Combined Services  2033.103448
# 7                            Wholesale & Retail Trade  1982.758621
# 8                                  Mining & Quarrying  1831.724138
# 9                                        Construction  1644.137931
# 10                          Health Care & Social Work  1621.379310
# 11                                          Education  1617.931034
# 12                          Health Care & Social Work  1599.310345
# 13  Publishing, Audio-Visual & Information Communi...  1597.931034
# 14                                        Real Estate  1574.482759
# 15                           Transportation & Storage  1567.586207
# 16      Professional, Scientific & Technical Services  1560.000000
# 17                                Finance & Insurance  1540.689655
# 18                                Finance & Insurance  1749.655172
# 19                           Wholesale & Retail Trade  1646.896552
# 20                   Arts, Entertainment & Recreation  1602.068966
# 21                           Transportation & Storage  1412.413793
# 22                                       Construction  1411.034483
# 23                                 Mining & Quarrying  1402.068966
# 24                                     Other Services  1377.931034
# 25                                        Real Estate  1364.827586
# 26                       Accommodation & Food Service  1364.137931
# 27                                 Mining & Quarrying  2226.896552
# 28                          Health Care & Social Work  1804.827586
# 29                                        Real Estate  1800.689655
# 30      Professional, Scientific & Technical Services  1787.586207
# 31  Publishing, Audio-Visual & Information Communi...  1843.750000
# 32                                      Manufacturing  1812.500000
# 33                           Transportation & Storage  1187.500000
# 34                                Finance & Insurance  1062.500000
# 35                          Health Care & Social Work  1062.500000
# 36  Publishing, Audio-Visual & Information Communi...  1031.250000
# 37                       Accommodation & Food Service   906.250000
# 38                           Transportation & Storage  1062.500000
# 39                           Electricity & Gas Supply   968.750000
# 40                    Water Supply & Waste Management   937.500000
# 41                       Accommodation & Food Service   937.500000
# 42  Publishing, Audio-Visual & Information Communi...   937.500000
# 43                                Finance & Insurance   937.500000
# 44                  Administrative & Support Services   937.500000
# 45  Public Administration & Defense; Compulsory So...   937.500000
# 46                           Electricity & Gas Supply  1343.750000
# 47  Public Administration & Defense; Compulsory So...  1281.250000
# 48                          Health Care & Social Work  1250.000000
# 49                                Finance & Insurance  1187.500000
# 50                           Transportation & Storage  1125.000000
# 51  Publishing, Audio-Visual & Information Communi...  1093.750000
# 52                                          Education  1093.750000
#
#     all_employees_salary
# 0            1982.068966
# 1            1982.068966
# 2            1982.068966
# 3            1982.068966
# 4            1982.068966
# 5            1982.068966
# 6            1982.068966
# 7            1982.068966
# 8            1538.810605
# 9            1538.810605
# 10           1538.810605
# 11           1538.810605
# 12           1538.810605
# 13           1538.810605
# 14           1538.810605
# 15           1538.810605
# 16           1538.810605
# 17           1538.810605
# 18           1522.068966
# 19           1522.068966
# 20           1522.068966
# 21           1362.068966
# 22           1362.068966
# 23           1362.068966
# 24           1362.068966
# 25           1362.068966
# 26           1362.068966
# 27           1712.413793
# 28           1712.413793
# 29           1712.413793
# 30           1712.413793
# 31           1625.000000
# 32           1625.000000
# 33           1000.000000
# 34           1000.000000
# 35           1000.000000
# 36           1000.000000
# 37            875.000000
# 38            906.250000
# 39            906.250000
# 40            906.250000
# 41            906.250000
# 42            906.250000
# 43            906.250000
# 44            906.250000
# 45            906.250000
# 46           1062.500000
# 47           1062.500000
# 48           1062.500000
# 49           1062.500000
# 50           1062.500000
# 51           1062.500000
# 52           1062.500000

# %% [markdown]
# ### 5. Cross-Country Wage Comparison by Education Level
#
# Comparing salaries between Japan and Taiwan across different education levels, with percentage differences calculated.

# %%
query = """
SELECT 
    Education,
    MAX(CASE WHEN Country = 'Japan' THEN salary END) as 'Japan (USD)',
    MAX(CASE WHEN Country = 'Taiwan' THEN salary END) as 'Taiwan (USD)',
    ROUND(
        (MAX(CASE WHEN Country = 'Japan' THEN salary END) - 
         MAX(CASE WHEN Country = 'Taiwan' THEN salary END)) * 100.0 / 
         MAX(CASE WHEN Country = 'Taiwan' THEN salary END), 2
    ) as '% Difference'
FROM (
    SELECT 
        Country,
        Education,
        Salary
    FROM wage_data
    WHERE Category = 'All Employees'
    GROUP BY Country, Education
)
GROUP BY Education
ORDER BY 
    CASE Education
        WHEN 'Junior High' THEN 1
        WHEN 'Senior High' THEN 2
        WHEN 'Junior College' THEN 3
        WHEN 'University' THEN 4
        WHEN 'Graduate School' THEN 5
        ELSE 6
    END
"""
diff = pd.read_sql_query(query, conn)
diff
# Out:
#          Education  Japan (USD)  Taiwan (USD)  % Difference
# 0      Junior High  1522.068966        875.00         73.95
# 1      Senior High  1362.068966        906.25         50.30
# 2   Junior College  1544.137931       1000.00         54.41
# 3       University  1712.413793       1062.50         61.17
# 4  Graduate School  1982.068966       1625.00         21.97

# %% [markdown]
# ### 6. Education Wage Premiums Within Each Country
#
# Analyzing the salary increases when advancing from Junior College to University, and from University to Graduate School in each country.

# %%
query = """
WITH base_salaries AS (
    SELECT 
        Country,
        Education,
        CASE 
            WHEN Population IS NOT NULL AND Population > 0 
            THEN SUM(Salary * Population) / SUM(Population)
            ELSE Salary
        END as salary
    FROM wage_data
    WHERE Category = 'All Employees'
    GROUP BY Country, Education
)
SELECT 
    Country,
    MAX(CASE WHEN Education = 'Junior College' THEN salary END) as 'Junior College (USD)',
    MAX(CASE WHEN Education = 'University' THEN salary END) as 'University (USD)',
    MAX(CASE WHEN Education = 'Graduate School' THEN salary END) as 'Graduate School (USD)',
    ROUND(
        (MAX(CASE WHEN Education = 'University' THEN salary END) - 
         MAX(CASE WHEN Education = 'Junior College' THEN salary END)) * 100.0 / 
         MAX(CASE WHEN Education = 'Junior College' THEN salary END), 2
    ) as 'Junior College → University (%)',
    ROUND(
        (MAX(CASE WHEN Education = 'Graduate School' THEN salary END) - 
         MAX(CASE WHEN Education = 'University' THEN salary END)) * 100.0 / 
         MAX(CASE WHEN Education = 'University' THEN salary END), 2
    ) as 'University → Graduate School (%)'
FROM base_salaries
GROUP BY Country
ORDER BY Country
"""

edu_premium = pd.read_sql_query(query, conn)
edu_premium
# Out:
#   Country  Junior College (USD)  University (USD)  Graduate School (USD)  \
# 0   Japan           1538.810605       1712.413793            1982.068966
# 1  Taiwan           1000.000000       1062.500000            1625.000000
#
#    Junior College → University (%)  University → Graduate School (%)
# 0                            11.28                             15.75
# 1                             6.25                             52.94

# %% [markdown]
# ### 7. Industry Wage Comparison Across Countries
#
# Comparing industry salaries between Japan and Taiwan, sorted by the percentage difference. This shows which industries have the largest wage gaps between the two countries.

# %%
query = """
WITH industry_salaries AS (
    SELECT 
        Category,
        Country,
        CASE 
            WHEN Population IS NOT NULL AND Population > 0 
            THEN SUM(Salary * Population) / SUM(Population)
            ELSE AVG(Salary)
        END as salary
    FROM wage_data
    WHERE Category_Type = 'Industry'
    GROUP BY Category, Country
)
SELECT 
    Category,
    MAX(CASE WHEN Country = 'Japan' THEN salary END) as 'Japan',
    MAX(CASE WHEN Country = 'Taiwan' THEN salary END) as 'Taiwan',
    ROUND(
        (MAX(CASE WHEN Country = 'Japan' THEN salary END) - 
         MAX(CASE WHEN Country = 'Taiwan' THEN salary END)) * 100.0 / 
         MAX(CASE WHEN Country = 'Taiwan' THEN salary END), 2
    ) as 'Percentage_Difference_Japan_vs_Taiwan'
FROM industry_salaries
GROUP BY Category
HAVING MAX(CASE WHEN Country = 'Japan' THEN salary END) IS NOT NULL 
   AND MAX(CASE WHEN Country = 'Taiwan' THEN salary END) IS NOT NULL
ORDER BY Percentage_Difference_Japan_vs_Taiwan DESC
"""

industry_comparison = pd.read_sql_query(query, conn)
industry_comparison
# Out:
#                                              Category        Japan     Taiwan  \
# 0                                  Mining & Quarrying  1939.482759  1031.2500
# 1                                         Real Estate  1783.228282  1000.0000
# 2                                        Construction  1654.068966   981.2500
# 3                            Wholesale & Retail Trade  1625.776581  1025.0000
# 4                                      Other Services  1514.206897   968.7500
# 5                        Accommodation & Food Service  1517.002432   975.0000
# 6                    Arts, Entertainment & Recreation  1504.842661   968.7500
# 7                                           Education  1648.275862  1109.3750
# 8       Professional, Scientific & Technical Services  1616.137931  1093.7500
# 9                                 Finance & Insurance  1698.190361  1171.8750
# 10                          Health Care & Social Work  1605.517241  1132.8125
# 11                                      Manufacturing  1537.931734  1125.0000
# 12  Publishing, Audio-Visual & Information Communi...  1654.206897  1226.5625
# 13                           Transportation & Storage  1548.000000  1156.2500
# 14                           Electricity & Gas Supply  1551.172414  1218.7500
#
#     Percentage_Difference_Japan_vs_Taiwan
# 0                                   88.07
# 1                                   78.32
# 2                                   68.57
# 3                                   58.61
# 4                                   56.31
# 5                                   55.59
# 6                                   55.34
# 7                                   48.58
# 8                                   47.76
# 9                                   44.91
# 10                                  41.73
# 11                                  36.71
# 12                                  34.87
# 13                                  33.88
# 14                                  27.28

# %% [markdown]
# ### 8. Close Database Connection
#
# Clean up resources by closing the SQLite connection.

# %%
conn.close()
